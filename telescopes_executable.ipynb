# %%
from astropy import units as u
import telescope


# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,9)

# %%
##running telescope.py for Hawaii-2RG

h2rg = Telescope( 'J', 0.5*u.arcsec, 30*u.cm, 0.4, 1.0, 0.8*u.electron, 0.0001*u.erg/u.cm**2/u.sr/u.s,
                    0.001 *u.electron/u.pix/u.s, 15 *(u.electron**0.5/u.pix**0.5), 1.*u.pix)

# %%
h2rg.sn_v_time_plot(10, 300, 20, 1)
h2rg.sn_v_mag_plot(15, 29, 300, 1)

# %%
##running telescope.py for NIRC
#filt, phot_r, D, tau_ins, tau_atm, eta, L_ins, Dark, Ron, n_pixel
#r_phot = aperature in pixels*arcsec/pix = 78.5*0.02

nirc = Telescope( 'J', 1.57*u.arcsec, 1000*u.cm, 0.7, 0.7, 0.8*u.electron, 0.0001*u.erg/u.cm**2/u.sr/u.s,
                    0.1 *u.electron/u.pix/u.s, 38 *(u.electron**0.5/u.pix**0.5), 1.*u.pix)

# %%
nirc.sn_v_time_plot(10, 300, 20, 1)
nirc.sn_v_mag_plot(15, 29, 300, 1)
